# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.tree import DecisionTreeRegressor

# %%
df = pd.read_csv('/content/ev_charging_high_quality_dataset.csv')
df.head()
# Out:
#    traffic_density  population_density  commercial_activity_index  \
# 0       323.880318         1456.628792                   0.303635
# 1       246.760105         1575.735132                   0.331088
# 2       805.278930         4628.365649                   0.301178
# 3       827.671050         9378.301192                   0.500916
# 4       663.065585         8445.402718                   0.458580
#
#    green_cover_percent  air_quality_index  electric_vehicle_count  \
# 0            35.143297         168.776378              921.464782
# 1            44.559467         195.319060              641.639746
# 2            57.341793         175.068105              697.601688
# 3            39.616605         140.267273              732.843713
# 4            30.675270         139.897705              891.165795
#
#    grid_capacity_mw  solar_potential_kw  predicted_utilization_percent
# 0         22.405718         1660.105889                       1.953770
# 1         29.794447         4716.292809                       2.134418
# 2         36.210375         2239.169656                       4.642068
# 3         32.254566         6641.752188                       7.468031
# 4         28.217034         4666.392149                       7.230984

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   traffic_density                400 non-null    float64
#  1   population_density             400 non-null    float64
#  2   commercial_activity_index      400 non-null    float64
#  3   green_cover_percent            400 non-null    float64
#  4   air_quality_index              400 non-null    float64
#  5   electric_vehicle_count         400 non-null    float64
#  6   grid_capacity_mw               400 non-null    float64
#  7   solar_potential_kw             400 non-null    float64
#  8   predicted_utilization_percent  400 non-null    float64
# dtypes: float64(9)
# memory usage: 28.3 KB

# %%
print(df.isnull().sum())
# Out:
# traffic_density                  0
# population_density               0
# commercial_activity_index        0
# green_cover_percent              0
# air_quality_index                0
# electric_vehicle_count           0
# grid_capacity_mw                 0
# solar_potential_kw               0
# predicted_utilization_percent    0
# dtype: int64

# %%
df.head()
# Out:
#    traffic_density  population_density  commercial_activity_index  \
# 0       323.880318         1456.628792                   0.303635
# 1       246.760105         1575.735132                   0.331088
# 2       805.278930         4628.365649                   0.301178
# 3       827.671050         9378.301192                   0.500916
# 4       663.065585         8445.402718                   0.458580
#
#    green_cover_percent  air_quality_index  electric_vehicle_count  \
# 0            35.143297         168.776378              921.464782
# 1            44.559467         195.319060              641.639746
# 2            57.341793         175.068105              697.601688
# 3            39.616605         140.267273              732.843713
# 4            30.675270         139.897705              891.165795
#
#    grid_capacity_mw  solar_potential_kw  predicted_utilization_percent
# 0         22.405718         1660.105889                       1.953770
# 1         29.794447         4716.292809                       2.134418
# 2         36.210375         2239.169656                       4.642068
# 3         32.254566         6641.752188                       7.468031
# 4         28.217034         4666.392149                       7.230984

# %%
x = df.drop(columns=["predicted_utilization_percent"])
x
# Out:
#      traffic_density  population_density  commercial_activity_index  \
# 0         323.880318         1456.628792                   0.303635
# 1         246.760105         1575.735132                   0.331088
# 2         805.278930         4628.365649                   0.301178
# 3         827.671050         9378.301192                   0.500916
# 4         663.065585         8445.402718                   0.458580
# ..               ...                 ...                        ...
# 395       154.771317         2661.960241                   0.555703
# 396       740.284470         2116.823015                   0.432884
# 397       577.935054         6060.630057                   0.309602
# 398       914.119370         9659.650031                   0.699128
# 399       202.576055         1656.046896                   0.804118
#
#      green_cover_percent  air_quality_index  electric_vehicle_count  \
# 0              35.143297         168.776378              921.464782
# 1              44.559467         195.319060              641.639746
# 2              57.341793         175.068105              697.601688
# 3              39.616605         140.267273              732.843713
# 4              30.675270         139.897705              891.165795
# ..                   ...                ...                     ...
# 395            59.034366          86.141241              151.644198
# 396            53.058833         189.066407              226.739115
# 397            17.204743         121.987301              273.438795
# 398            16.884609         156.396382              663.185691
# 399            56.425886         120.857934              532.554707
#
#      grid_capacity_mw  solar_potential_kw
# 0           22.405718         1660.105889
# 1           29.794447         4716.292809
# 2           36.210375         2239.169656
# 3           32.254566         6641.752188
# 4           28.217034         4666.392149
# ..                ...                 ...
# 395         21.978975         7639.878997
# 396         26.741202         6043.154038
# 397         16.256178         7689.246210
# 398         14.376765         7518.241338
# 399         28.698182         7089.975739
#
# [400 rows x 8 columns]

# %%
y = df["predicted_utilization_percent"]
y
# Out:
# 0      1.953770
# 1      2.134418
# 2      4.642068
# 3      7.468031
# 4      7.230984
#          ...
# 395    2.439091
# 396    2.173969
# 397    4.757687
# 398    7.985254
# 399    2.430934
# Name: predicted_utilization_percent, Length: 400, dtype: float64

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
ypred= model.predict(xtest)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mae = mean_absolute_error(ytest, ypred)
mse = mean_squared_error(ytest, ypred)
r2 = r2_score(ytest, ypred)

# %%
print("mean_absolute_error:", mae)
print("mean_squared_error:", mse)
print("r2_score:", r2)
# Out:
# mean_absolute_error: 0.17084751252037567
# mean_squared_error: 0.04120522630024115
# r2_score: 0.9854342960478659

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor()
dt.fit(xtrain, ytrain)
# Out:
# DecisionTreeRegressor()

# %%
print("mean_absolute_error:", mae)
print("mean_squared_error:", mse)
print("r2_score:", r2)
# Out:
# mean_absolute_error: 0.17084751252037567
# mean_squared_error: 0.04120522630024115
# r2_score: 0.9854342960478659
